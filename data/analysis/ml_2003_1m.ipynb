# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_ratings = pd.read_parquet("../ml-2003-1m/ratings.parquet")
df_users = pd.read_parquet("../ml-2003-1m/users.parquet")
df_movies = pd.read_parquet("../ml-2003-1m/movies.parquet")

# %%
display(df_ratings)
display(df_users)
display(df_movies)
